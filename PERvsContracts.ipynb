# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import contract data
contracts = pd.read_csv("PlayerContracts.csv")

#remove player identifier
c1 = contracts["Player"]
c0 = []
for name in c1:
    n,a = name.split("\\")
    c0.append(n)

c0 = pd.DataFrame(c0)

contracts["Player"] = c0

#show data
contracts
# Out:
#                  Player   Tm   2017-18     2018-19     2019-20     2020-21  \
# 0         Stephen Curry  GSW  34682550  37457154.0  40231758.0  43006362.0
# 1          LeBron James  CLE  33285709  35607968.0         NaN         NaN
# 2          Paul Millsap  DEN  31269231  29730769.0  30500000.0         NaN
# 3        Gordon Hayward  BOS  29727900  31214295.0  32700690.0  34187085.0
# 4         Blake Griffin  LAC  29700000  32076000.0  34452000.0  36828000.0
# 5           Mike Conley  MEM  28530608  30521115.0  32511623.0  34504132.0
# 6     Russell Westbrook  OKC  28530608  30670404.0         NaN         NaN
# 7          James Harden  HOU  28299339  30431854.0  37800000.0  40824000.0
# 8         DeMar DeRozan  TOR  27739975  27739975.0  27739975.0  27739975.0
# 9            Al Horford  BOS  27734405  28928710.0  30123015.0         NaN
# 10      Carmelo Anthony  NYK  26243760  27928140.0         NaN         NaN
# ...
